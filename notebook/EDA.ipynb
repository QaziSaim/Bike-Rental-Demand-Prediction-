# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('data\SeoulBikeData.csv',encoding='latin1')

# %%
data.head()
# Out:
#          Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0  01/12/2017                254     0             -5.2           37
# 1  01/12/2017                204     1             -5.5           38
# 2  01/12/2017                173     2             -6.0           39
# 3  01/12/2017                107     3             -6.2           40
# 4  01/12/2017                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# ...

# %%
sns.heatmap(data.corr(numeric_only=True),annot=True,fmt=".1f",cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# # 5.1. Distribution of temperature for rented bike counts

# %%
sns.histplot(data['Temperature(°C)'],kde=True)
plt.title("Distribution for rented bike counts vs temperature")
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.pie(data['Temperature(°C)'].value_counts().head(5),autopct='%1.1f%%')
plt.title("Distribution for rented bike counts vs temperature")
# Out:
# Text(0.5, 1.0, 'Distribution for rented bike counts vs temperature')

# %%
data['Seasons'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
data.columns
# Out:
# Index(['Date', 'Rented Bike Count', 'Hour', 'Temperature(°C)', 'Humidity(%)',
#        'Wind speed (m/s)', 'Visibility (10m)', 'Dew point temperature(°C)',
#        'Solar Radiation (MJ/m2)', 'Rainfall(mm)', 'Snowfall (cm)', 'Seasons',
#        'Holiday', 'Functioning Day'],
#       dtype='object')

# %%
data.groupby('Seasons')[['Rented Bike Count','Temperature(°C)']].sum().reset_index()['Rented Bike Count'].plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Rented Bike Count'>

# %%
data['Humidity(%)'].unique()
# Out:
# array([37, 38, 39, 40, 36, 35, 27, 24, 21, 23, 25, 26, 54, 58, 66, 77, 79,
#        81, 83, 84, 87, 86, 82, 68, 57, 49, 41, 48, 51, 53, 52, 55, 56, 69,
#        71, 73, 75, 91, 92, 89, 85, 76, 90, 88, 47, 30, 29, 32, 43, 45, 44,
#        42, 34, 33, 31, 28, 46, 59, 78, 70, 64, 60, 94, 93, 96, 65, 50, 74,
#        63, 61, 72, 62, 22, 67, 80, 95, 15, 20, 17, 18, 16, 19, 14, 97, 98,
#        10, 13, 12, 11,  0], dtype=int64)

# %%
sns.histplot(x=data['Wind speed (m/s)'])
plt.show()
